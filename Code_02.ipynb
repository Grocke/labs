# %% [markdown]
# <a href="https://colab.research.google.com/github/Grocke/labs/blob/master/Code_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introdução
#
# Como vimos na aula passada, uma imagem pode ser preto e branca, tons de cinza ou colorida. Ainda, conseguimos extrair informações das imagens através dos histogramas.
#
# Para esta atividade, utilizaremos três imagens coloridas, retiradas do unsplash:
#
# * johannes-plenio-RwHv7LgeC7s-unsplash.jpg
# * claudio-testa--SO3JtE3gZo-unsplash.jpg
# * bailey-zindel-NRQV-hBF10M-unsplash.jpg
#
# As imagens se encontram na pasta compartilhada com vocês, na disciplina.
#
# No espaço de código abaixo, escreva os `imports` necessários para começarmos a atividade.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# # 1a parte
#
# No espaço de código abaixo, plote as 3 imagens, uma ao lado da outra. Ainda, plote o histograma de cada canal de cor (R - Vermelho, G - Verde e B - Azul) abaixo da respectiva imagem.

# %%
imagem_um = Image.open('/content/drive/My Drive/Colab Notebooks/bailey-zindel-NRQV-hBF10M-unsplash.jpg')
imagem_dois = Image.open('/content/drive/My Drive/Colab Notebooks/claudio-testa--SO3JtE3gZo-unsplash.jpg')
imagem_tres = Image.open('/content/drive/My Drive/Colab Notebooks/johannes-plenio-RwHv7LgeC7s-unsplash.jpg')

plt.figure(figsize=(20,4))

plt.subplot(131)
plt.title('Imagem 1')
plt.axis('off')
plt.imshow(imagem_um)

plt.subplot(132)
plt.title('Imagem 2')
plt.axis('off')
plt.imshow(imagem_dois)

plt.subplot(133)
plt.title('Imagem 3')
plt.axis('off')
plt.imshow(imagem_tres)

plt.show()

#subplot(4,3,10)

imagem_um_arr = np.array(imagem_um)
imagem_dois_arr = np.array(imagem_dois)
imagem_tres_arr = np.array(imagem_tres)

# Histograma 1

red = imagem_um_arr[:,:,0]
green = imagem_um_arr[:,:,1]
blue = imagem_um_arr[:,:,2]

plt.figure(figsize=(20,4))

plt.subplot(131)
plt.hist(red.ravel(), color='red')

plt.subplot(132)
plt.hist(green.ravel(), color='green')

plt.subplot(133)
plt.hist(blue.ravel(), color='blue')

# Histograma 2

red = imagem_dois_arr[:,:,0]
green = imagem_dois_arr[:,:,1]
blue = imagem_dois_arr[:,:,2]
plt.figure(figsize=(20,4))

plt.subplot(131)
plt.hist(red.ravel(), color='red')

plt.subplot(132)
plt.hist(green.ravel(), color='green')

plt.subplot(133)
plt.hist(blue.ravel(), color='blue')

# Histograma 3

red = imagem_tres_arr[:,:,0]
green = imagem_tres_arr[:,:,1]
blue = imagem_tres_arr[:,:,2]
plt.figure(figsize=(20,4))

plt.subplot(131)
plt.hist(red.ravel(), color='red')

plt.subplot(132)
plt.hist(green.ravel(), color='green')

plt.subplot(133)
plt.hist(blue.ravel(), color='blue')
# Out:
# (array([4461131., 2393595., 2436747., 1639435.,  661911.,  254887.,
#          151647.,  123248.,  148814.,  448201.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Olhando para os gráficos gerados, discorram comparando os resultados.

# %% [markdown]
# > Coloque a reposta aqui!
#
# Na imagem 1 temos algumas temos alta concentração de tons vermelhos entre 0 e 50 e do 200 ao 250. No verde temos uma crescente de tons entre 0 e 60, logo depois uma descresente entre 60 e 150 e voltando a subir do 150 até 250. Nos tons azuis temos uma crescente do 0 até + ou - 240.
#
# Na imagem 2 temos uma crescente entre os valores 0 e + ou - 140 e logo em seguida uma decrescente no tom vermelho. No tom verde tems o mesmo comportamento, uma crescente entre 0 e + ou menos 170. Já no tom azul, começamos com alta concentração apartir do 0 e logo depois do 50 começa a decair.
#
# Na imagem 3 começa com uma elevação do 0 até 100, uma certa estabelidade até  + ou - 220 e uma ultima elevação até 250. No verde tens uma consentração alta no 0 e descrece até o final. No tom azul temos o mesmo tipo de comportamento que o tom verde.

# %% [markdown]
# # 2a parte
#
# Escolha uma das imagens acima, para continuarmos os experimentos.
#
# Vamos gerar algumas imagens preto e branco, utilizando limiares diferentes:
#
# *  45
# *  100
# *  145
# *  200
# *  245
#
# Escreva o código no espaço abaixo.

# %%
imagem_cinza = np.mean(imagem_dois_arr, axis=2)
img_cinza_45 = np.array(imagem_cinza)
img_cinza_45[img_cinza_45 >= 45] = 255
img_cinza_45[img_cinza_45 < 45] = 0
plt.imshow(Image.fromarray(img_cinza_45))
plt.show()

# %% [markdown]
# Plote as imagens geradas. (Escreva o código no espaço abaixo)

# %%
imagem_cinza = np.mean(imagem_dois_arr, axis=2)
img_cinza_100 = np.array(imagem_cinza)
img_cinza_100[img_cinza_100 >= 100] = 255
img_cinza_100[img_cinza_100 < 100] = 0
plt.imshow(Image.fromarray(img_cinza_100))
plt.show()

# %%
imagem_cinza = np.mean(imagem_dois_arr, axis=2)
img_cinza_145 = np.array(imagem_cinza)
img_cinza_145[img_cinza_145 >= 145] = 255
img_cinza_145[img_cinza_145 < 145] = 0
plt.imshow(Image.fromarray(img_cinza_145))
plt.show()

# %%
imagem_cinza = np.mean(imagem_dois_arr, axis=2)
img_cinza_200 = np.array(imagem_cinza)
img_cinza_200[img_cinza_200 >= 200] = 255
img_cinza_200[img_cinza_200 < 200] = 0
plt.imshow(Image.fromarray(img_cinza_200))
plt.show()

# %%
imagem_cinza = np.mean(imagem_dois_arr, axis=2)
img_cinza_245 = np.array(imagem_cinza)
img_cinza_245[img_cinza_245 >= 245] = 255
img_cinza_245[img_cinza_245 < 245] = 0
plt.imshow(Image.fromarray(img_cinza_245))
plt.show()

# %% [markdown]
# O que você consegue extrair deste experimento? Escreva no espaço abaixo.

# %% [markdown]
# > Responda aqui.
#
#
# Conforme mudamos os valores dos tons cinzas, deixamos a imagem cada vez mais escura.
